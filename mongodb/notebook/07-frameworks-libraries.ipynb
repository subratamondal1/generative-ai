# %% [markdown]
# # 7. Frameworks, Libraries and APIs

# %% [markdown]
# ### Import Libraries

# %%
import getpass, os, pymongo, pprint
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_mongodb import MongoDBAtlasVectorSearch
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain.prompts import PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pymongo import MongoClient
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ### Load Environment Variables

# %%
OPENAI_API_KEY: str | None = os.getenv(
    key="OPENAI_API_KEY",
    default=None,
)
MONGODB_CONNECTION_STRING: str | None = os.getenv(
    key="MONGODB_CONNECTION_STRING",
    default=None,
)

# %% [markdown]
# ### Connect to MongoDB

# %%
# Connect to MongoDB
client = MongoClient(
    host=MONGODB_CONNECTION_STRING, tls=True, tlsAllowInvalidCertificates=True
)

# %%
mm_ai_db = client.get_database(name="mm_ai")
print(mm_ai_db)
mm_ai_db.list_collection_names()
# Out:
# Database(MongoClient(host=['mmdev-shard-00-01.z7q8g.mongodb.net:27017', 'mmdev-shard-00-02.z7q8g.mongodb.net:27017', 'mmdev-shard-00-00.z7q8g.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-b4um4g-shard-0', tls=True, tlsallowinvalidcertificates=True, tlsdisableocspendpointcheck=True), 'mm_ai')
# ['test']

# %%
ca_coll = mm_ai_db.get_collection(name="test")
print(ca_coll)
ca_coll.list_search_indexes()
# Out:
# Collection(Database(MongoClient(host=['mmdev-shard-00-01.z7q8g.mongodb.net:27017', 'mmdev-shard-00-02.z7q8g.mongodb.net:27017', 'mmdev-shard-00-00.z7q8g.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-b4um4g-shard-0', tls=True, tlsallowinvalidcertificates=True, tlsdisableocspendpointcheck=True), 'mm_ai'), 'test')

# %%
vector_search_index: str = "vector_index"

# %% [markdown]
# ### Fetch and split public PDF documents

# %%
from langchain_core.documents.base import Document
from pprint import pprint

URL: str = "https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP"

# Load Document
loader = PyPDFLoader(file_path=URL)
data: list[Document] = loader.load()

print(len(data), data)
pprint(data[0])
# Out:
# 21 [Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 0}, page_content='MongoDB Atlas Best PracticesJanuary 2019\nA MongoDB White Paper\n'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 1}, page_content='Table of Contents\n1Introduction\n2Preparing for a MongoDB Deployment\n9Scaling a MongoDB Atlas Cluster\n11Continuous Availability & Data Consistency\n12Managing MongoDB\n16Security\n17Business Intelligence with MongoDB Atlas\n18Considerations for Proofs of Concept\n18MongoDB Stitch: Serverless Platform from MongoDB\n19We Can Help\n19Resources'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 2}, page_content='Introduction\nMongoDB Atlas provides all of the features of MongoDB,\nwithout the operational heavy lifting required for any new\napplication. MongoDB Atlas is available on-demand\nthrough a pay-as-you-go model and billed on an hourly\nbasis, letting you focus on what you do best.\nIt’s easy to get started – use a simple GUI to select the\ninstance size, region, and features you need. MongoDB\nAtlas provides:\n• Security features to protect access to your data\n• Built in replication for always-on availability, tolerating\ncomplete data center failure\n• Backups and point in time recovery to protect against\ndata corruption\n• Fine-grained monitoring to let you know when to scale.\nAdditional instances can be provisioned with the push\nof a button\n• Automated patching and one-click upgrades for new\nmajor versions of the database, enabling you to take\nadvantage of the latest and greatest MongoDB features\n• A choice of cloud providers, regions, and billing options\nMongoDB Atlas is versatile. It’s great for everything from a\nquick Proof of Concept, to test/QA environments, to\ncomplete production clusters. If you decide you want to\nbring operations back under your control, it is easy to move\nyour databases onto your own infrastructure and manage\nthem using MongoDB Ops Manager or MongoDB Cloud\nManager. The user experience across MongoDB Atlas,\nCloud Manager, and Ops Manager is consistent, ensuring\nthat disruption is minimal if you decide to migrate to your\nown infrastructure.\nMongoDB Atlas is automated, it’s easy, and it’s from the\ncreators of MongoDB. Learn more and take it for a spin.\nWhile MongoDB Atlas radically simplifies the operation of\nMongoDB there are still some decisions to take to ensure\nthe best performance and reliability for your application.\nThis paper provides guidance on best practices for\ndeploying, managing, and optimizing the performance of\nyour database with MongoDB Atlas.\nThis guide outlines considerations for achieving\nperformance at scale with MongoDB Atlas across a\nnumber of key dimensions, including instance size\n1'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 3}, page_content="selection, application patterns, schema design and\nindexing, and disk I/O. While this guide is broad in scope, it\nis not exhaustive. Following the recommendations in this\nguide will provide a solid foundation for ensuring optimal\napplication performance.\nFor the most detailed information on specific topics, please\nsee the on-line documentation at mongodb.com. Many\nlinks are provided throughout this white paper to help\nguide users to the appropriate resources.\nPreparing for a MongoDB\nDeployment\nSchema Design\nDevelopers and data architects should work together to\ndevelop the right data model, and they should invest time in\nthis exercise early in the project. The requirements of the\napplication should drive the data model, updates, and\nqueries of your MongoDB system. Given MongoDB's\ndynamic schema, developers and data architects can\ncontinue to iterate on the data model throughout the\ndevelopment and deployment processes to optimize\nperformance and  ...
# Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 0}, page_content='MongoDB Atlas Best PracticesJanuary 2019\nA MongoDB White Paper\n')

# %%
# Split PDF into Documents
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=20,
)

docs = text_splitter.split_documents(documents=data)

print(len(docs), docs)
pprint(docs[0])
# Out:
# 419 [Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 0}, page_content='MongoDB Atlas Best PracticesJanuary 2019\nA MongoDB White Paper'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 1}, page_content='Table of Contents\n1Introduction\n2Preparing for a MongoDB Deployment\n9Scaling a MongoDB Atlas Cluster\n11Continuous Availability & Data Consistency\n12Managing MongoDB\n16Security'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 1}, page_content='16Security\n17Business Intelligence with MongoDB Atlas\n18Considerations for Proofs of Concept\n18MongoDB Stitch: Serverless Platform from MongoDB\n19We Can Help\n19Resources'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 2}, page_content='Introduction\nMongoDB Atlas provides all of the features of MongoDB,\nwithout the operational heavy lifting required for any new\napplication. MongoDB Atlas is available on-demand'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 2}, page_content='through a pay-as-you-go model and billed on an hourly\nbasis, letting you focus on what you do best.\nIt’s easy to get started – use a simple GUI to select the'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 2}, page_content='instance size, region, and features you need. MongoDB\nAtlas provides:\n• Security features to protect access to your data\n• Built in replication for always-on availability, tolerating'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 2}, page_content='complete data center failure\n• Backups and point in time recovery to protect against\ndata corruption\n• Fine-grained monitoring to let you know when to scale.'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 2}, page_content='Additional instances can be provisioned with the push\nof a button\n• Automated patching and one-click upgrades for new\nmajor versions of the database, enabling you to take'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 2}, page_content='advantage of the latest and greatest MongoDB features\n• A choice of cloud providers, regions, and billing options\nMongoDB Atlas is versatile. It’s great for everything from a'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 2}, page_content='quick Proof of Concept, to test/QA environments, to\ncomplete production clusters. If you decide you want to\nbring operations back under your control, it is easy to move'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 2}, page_content='your databases onto your own infrastructure and manage\nthem using MongoDB Ops Manager or MongoDB Cloud\nManager. The user experience across MongoDB Atlas,'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 2}, page_content='Cloud Manager, and Ops Manager is consistent, ensuring\nthat disruption is minimal if you decide to migrate to your\nown infrastructure.\nMongoDB Atlas is automated, it’s easy, and it’s from the'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 2}, page_content='creators of MongoDB. Learn more and take it for a spin.\nWhile MongoDB Atlas radically simplifies the operation of\nMongoDB there are still some decisions to take to ensure'), Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 2}, page_content='the best performance and reliability for your application.\nThis p ...
# Document(metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 0}, page_content='MongoDB Atlas Best PracticesJanuary 2019\nA MongoDB White Paper')

# %% [markdown]
# ### Create Vector Store

# %%
# Instantiate Embedding Model
embedding_model = OpenAIEmbeddings(
    model="text-embedding-3-large",
    dimensions=3072,
    disallowed_special=(),
)

# %%
# Check if vector search index already exists
existing_indexes = list(ca_coll.list_search_indexes())
print(existing_indexes)
# Out:
# [{'id': '678372d5219f0d65a7001e98', 'name': 'vector_index', 'type': 'vectorSearch', 'status': 'READY', 'queryable': True, 'latestDefinitionVersion': {'version': 0, 'createdAt': datetime.datetime(2025, 1, 12, 7, 44, 21, 691000)}, 'latestDefinition': {'fields': [{'type': 'vector', 'path': 'embedding', 'numDimensions': 3072, 'similarity': 'cosine'}, {'type': 'filter', 'path': 'page'}]}, 'statusDetail': [{'hostname': 'atlas-b4um4g-shard-00-02', 'status': 'READY', 'queryable': True, 'mainIndex': {'status': 'READY', 'queryable': True, 'definitionVersion': {'version': 0, 'createdAt': datetime.datetime(2025, 1, 12, 7, 44, 21)}, 'definition': {'fields': [{'type': 'vector', 'path': 'embedding', 'numDimensions': 3072, 'similarity': 'cosine'}, {'type': 'filter', 'path': 'page'}]}}}, {'hostname': 'atlas-b4um4g-shard-00-00', 'status': 'READY', 'queryable': True, 'mainIndex': {'status': 'READY', 'queryable': True, 'definitionVersion': {'version': 0, 'createdAt': datetime.datetime(2025, 1, 12, 7, 44, 21)}, 'definition': {'fields': [{'type': 'vector', 'path': 'embedding', 'numDimensions': 3072, 'similarity': 'cosine'}, {'type': 'filter', 'path': 'page'}]}}}, {'hostname': 'atlas-b4um4g-shard-00-01', 'status': 'READY', 'queryable': True, 'mainIndex': {'status': 'READY', 'queryable': True, 'definitionVersion': {'version': 0, 'createdAt': datetime.datetime(2025, 1, 12, 7, 44, 21)}, 'definition': {'fields': [{'type': 'vector', 'path': 'embedding', 'numDimensions': 3072, 'similarity': 'cosine'}, {'type': 'filter', 'path': 'page'}]}}}]}]

# %%
# ca_coll.drop_search_index(name="vector_index")

# %%
# Create the Vector Store
vector_store = MongoDBAtlasVectorSearch.from_documents(
    documents=docs,
    embedding=embedding_model,
    collection=ca_coll,
    index_name=vector_search_index,
)

# %%
# Create Index
from pymongo.operations import SearchIndexModel

# Define search index model
search_index_model = SearchIndexModel(
    definition={
        "fields": [
            {
                "type": "vector",
                "path": "embedding",
                "numDimensions": 3072,
                "similarity": "cosine",
            },
            {
                "type": "filter",
                "path": "page",
            },
        ]
    },
    name=vector_search_index,
    type="vectorSearch",
)

ca_coll.create_search_index(model=search_index_model)
print("Vector search index created successfully.")
# Out:
# Vector search index created successfully.

# %% [markdown]
# ### Langchain Semantic Search with Score

# %%
query: str = "MongoDB Atlas Security"

result = vector_store.similarity_search_with_score(
    query=query,
    k=3,
)
pprint(object=result)
# Out:
# [(Document(metadata={'_id': '678373aea320cfc6a18b74c8', 'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 17}, page_content='MongoDB Atlas features extensive capabilities to defend,\ndetect, and control access to MongoDB, offering among\nthe most complete security controls of any modern\ndatabase:'),
#   0.8972679376602173),
#  (Document(metadata={'_id': '678370aaa320cfc6a18b7325', 'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 17}, page_content='MongoDB Atlas features extensive capabilities to defend,\ndetect, and control access to MongoDB, offering among\nthe most complete security controls of any modern\ndatabase:'),
#   0.89713454246521),
#  (Document(metadata={'_id': '678373aea320cfc6a18b74cb', 'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 17}, page_content='automatically enabled.\nReview the security section of the MongoDB Atlas\ndocumentation to learn more about each of the security\nfeatures discussed below.\nIP Whitelisting'),
#   0.862579345703125)]

# %% [markdown]
# ### Semantic Search with Pre-Filtering
# > Pre-filtering narrows down the Search Space before performing a more computationally intensive vector search. Benefits: Increased Performance, Improved Accuracy and Enhanced Query Relevance.

# %%
query: str = "MongoDB Atlas Security"

result = vector_store.similarity_search_with_score(
    query=query,
    k=3,
    pre_filter={
        "page": {
            "$eq": 17,
        },
    },
)
pprint(object=result)
# Out:
# [(Document(metadata={'_id': '678373aea320cfc6a18b74c8', 'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 17}, page_content='MongoDB Atlas features extensive capabilities to defend,\ndetect, and control access to MongoDB, offering among\nthe most complete security controls of any modern\ndatabase:'),
#   0.8972679376602173),
#  (Document(metadata={'_id': '678370aaa320cfc6a18b7325', 'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 17}, page_content='MongoDB Atlas features extensive capabilities to defend,\ndetect, and control access to MongoDB, offering among\nthe most complete security controls of any modern\ndatabase:'),
#   0.89713454246521),
#  (Document(metadata={'_id': '678373aea320cfc6a18b74cb', 'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 17}, page_content='automatically enabled.\nReview the security section of the MongoDB Atlas\ndocumentation to learn more about each of the security\nfeatures discussed below.\nIP Whitelisting'),
#   0.862579345703125)]

# %% [markdown]
# ### Implementing a basic RAG with Langchain
# 1. Setup a MongoDB Atlas Vector Search Retriever for Similarity-Based Search.
# 2. Return the 10 most relevant documents.
# 3. Utiliza a custom RAG prompt with a LLM to answer based on the retrieved documents.

# %%
# Instantiate Atlas Vector Search as a Retriever
retriever = vector_store.as_retriever(
    search_type="similarity",
    search_kwargs={
        "k": 3,
    },
)

retriever.get_relevant_documents(query=query)
# Out:
# [Document(metadata={'_id': '678373aea320cfc6a18b74c8', 'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 17}, page_content='MongoDB Atlas features extensive capabilities to defend,\ndetect, and control access to MongoDB, offering among\nthe most complete security controls of any modern\ndatabase:'),
#  Document(metadata={'_id': '678370aaa320cfc6a18b7325', 'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 17}, page_content='MongoDB Atlas features extensive capabilities to defend,\ndetect, and control access to MongoDB, offering among\nthe most complete security controls of any modern\ndatabase:'),
#  Document(metadata={'_id': '678373aea320cfc6a18b74cb', 'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 17}, page_content='automatically enabled.\nReview the security section of the MongoDB Atlas\ndocumentation to learn more about each of the security\nfeatures discussed below.\nIP Whitelisting')]

# %%
# Define a prompt template
template = """
Use the following pieces of context to answer the question at the end.If you don't know the answer, just say that you don't know, don't try to make up an answer.
{context}
Question: {question}
"""

custom_rag_prompt = PromptTemplate.from_template(template=template)

print(custom_rag_prompt)
# Out:
# input_variables=['context', 'question'] input_types={} partial_variables={} template="\nUse the following pieces of context to answer the question at the end.If you don't know the answer, just say that you don't know, don't try to make up an answer.\n{context}\nQuestion: {question}\n"

# %%
llm = ChatOpenAI(
    name="gpt-4o",
    api_key=OPENAI_API_KEY,
)
print(llm)
# Out:
# name='gpt-4o' client=<openai.resources.chat.completions.Completions object at 0x1174687a0> async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x11744c6e0> root_client=<openai.OpenAI object at 0x11742b7d0> root_async_client=<openai.AsyncOpenAI object at 0x11745edb0> model_kwargs={} openai_api_key=SecretStr('**********')

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
print(docs[0])
print(format_docs(docs=docs[0:5]))
# Out:
# page_content='MongoDB Atlas Best PracticesJanuary 2019
# A MongoDB White Paper' metadata={'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 0}
# MongoDB Atlas Best PracticesJanuary 2019
# A MongoDB White Paper
#
# Table of Contents
# 1Introduction
# 2Preparing for a MongoDB Deployment
# 9Scaling a MongoDB Atlas Cluster
# 11Continuous Availability & Data Consistency
# 12Managing MongoDB
# 16Security
#
# 16Security
# 17Business Intelligence with MongoDB Atlas
# 18Considerations for Proofs of Concept
# 18MongoDB Stitch: Serverless Platform from MongoDB
# 19We Can Help
# 19Resources
#
# Introduction
# MongoDB Atlas provides all of the features of MongoDB,
# without the operational heavy lifting required for any new
# application. MongoDB Atlas is available on-demand
#
# through a pay-as-you-go model and billed on an hourly
# basis, letting you focus on what you do best.
# It’s easy to get started – use a simple GUI to select the

# %%
# Construct a RAG Chain to answer question based on the data
rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | custom_rag_prompt
    | llm
    | StrOutputParser()
)

# %%
# Prompt the Chain
question = "How can I secure my MongoDB Atlas cluster?"
answer = rag_chain.invoke(input=question)

print(f"QUESTION: {question}")
print(f"ANSWER: {answer}")
# Out:
# QUESTION: How can I secure my MongoDB Atlas cluster?
# ANSWER: You can secure your MongoDB Atlas cluster by utilizing the security features such as IP whitelisting and other controls provided by MongoDB Atlas. For more information, review the security section of the MongoDB Atlas documentation.

# %%
# Return Source Documents
documents = retriever.get_relevant_documents(query=question)
print("Source Documents: ")
pprint(object=documents)
# Out:
# Source Documents:
# [Document(metadata={'_id': '678373aea320cfc6a18b74c8', 'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 17}, page_content='MongoDB Atlas features extensive capabilities to defend,\ndetect, and control access to MongoDB, offering among\nthe most complete security controls of any modern\ndatabase:'),
#  Document(metadata={'_id': '678370aaa320cfc6a18b7325', 'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 17}, page_content='MongoDB Atlas features extensive capabilities to defend,\ndetect, and control access to MongoDB, offering among\nthe most complete security controls of any modern\ndatabase:'),
#  Document(metadata={'_id': '678373aea320cfc6a18b74cb', 'source': 'https://query.prod.cms.rt.microsoft.com/cms/api/am/binary/RE4HkJP', 'page': 17}, page_content='automatically enabled.\nReview the security section of the MongoDB Atlas\ndocumentation to learn more about each of the security\nfeatures discussed below.\nIP Whitelisting')]
